# %% [markdown]
# # P10 standing initial guess — Hunt–Crossley points or spheres
#
# This notebook builds the one-node standing equilibrium used as the initial guess for overground tracking. Set `CONTACT_GEOMETRY` to `"spheres3"` (three per foot) or `"points"`, `"points6"`, `"spheres"` (two per foot), `"spheres5"` (five per foot), or `"spheres6"` (six per foot). Results are stored separately.

# %%
from pathlib import Path
import ctypes, os, subprocess, sys


subprocess.run([sys.executable, 'scripts/patch_biosym_0_1_8_py311.py'], check=True)
ipopt_library = os.environ.get('IPOPT_LIBRARY')
if ipopt_library:
    ctypes.CDLL(ipopt_library, mode=ctypes.RTLD_GLOBAL)

# %%
import jax
jax.config.update('jax_enable_x64', False)
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt
from biosym.model.model import load_model
from biosym.ocp.collocation import Collocation
from src.contact_huntcrossley import install as install_huntcrossley_contact
install_huntcrossley_contact()
from biosym.constraints.dynamics import calc_forces

CONTACT_GEOMETRY = 'spheres6'  # fixed shared six-sphere condition
CONTACT_GEOMETRY = CONTACT_GEOMETRY.lower().replace(' ', '').replace('_', '')
if CONTACT_GEOMETRY == '3spheres':
    CONTACT_GEOMETRY = 'spheres3'
if CONTACT_GEOMETRY == '6spheres':
    CONTACT_GEOMETRY = 'spheres6'
if CONTACT_GEOMETRY == '5spheres':
    CONTACT_GEOMETRY = 'spheres5'
if CONTACT_GEOMETRY == '6points':
    CONTACT_GEOMETRY = 'points6'
if CONTACT_GEOMETRY == 'points':
    MODEL_FILE = 'models/gait2d_scaled_p10/gait2d_scaled_huntcrossley_points.yaml'
    STANDING_CONFIG = 'standing_files_huntcrossley/standing_p1.yaml'
    OUTPUT_FILE = Path('result_HC/p10/huntcrossley_points/standing.pkl')
    PELVIS_LIFT_M = 0.051
elif CONTACT_GEOMETRY == 'points6':
    MODEL_FILE = 'models/gait2d_scaled_p10/gait2d_scaled_huntcrossley_6points.yaml'
    STANDING_CONFIG = 'standing_files_huntcrossley/standing_p1_6points.yaml'
    OUTPUT_FILE = Path('result_HC/p10/huntcrossley_6points/standing.pkl')
    PELVIS_LIFT_M = 0.05022
elif CONTACT_GEOMETRY == 'spheres':
    MODEL_FILE = 'models/gait2d_scaled_p10/gait2d_scaled_huntcrossley_2spheres.yaml'
    STANDING_CONFIG = 'standing_files_huntcrossley/standing_p1_spheres.yaml'
    OUTPUT_FILE = Path('result_HC/p10/huntcrossley_2spheres/standing.pkl')
    PELVIS_LIFT_M = 0.081
elif CONTACT_GEOMETRY == 'spheres3':
    MODEL_FILE = 'models/gait2d_scaled_p10/gait2d_scaled_huntcrossley_3spheres.yaml'
    STANDING_CONFIG = 'standing_files_huntcrossley/standing_p10_3spheres.yaml'
    OUTPUT_FILE = Path('result_HC/p10/huntcrossley_3spheres/standing.pkl')
    PELVIS_LIFT_M = 0.085
elif CONTACT_GEOMETRY == 'spheres5':
    MODEL_FILE = 'models/gait2d_scaled_p10/gait2d_scaled_huntcrossley_5spheres.yaml'
    STANDING_CONFIG = 'standing_files_huntcrossley/standing_p1_5spheres.yaml'
    OUTPUT_FILE = Path('result_HC/p10/huntcrossley_5spheres/standing.pkl')
    PELVIS_LIFT_M = 0.04995
elif CONTACT_GEOMETRY == 'spheres6':
    MODEL_FILE = 'models/gait2d_scaled_p10/gait2d_scaled_huntcrossley_6spheres.yaml'
    STANDING_CONFIG = 'standing_files_huntcrossley/standing_p10_6spheres.yaml'
    OUTPUT_FILE = Path('result_HC/p10/huntcrossley_6spheres/standing.pkl')
    PELVIS_LIFT_M = 0.08022
else:
    raise ValueError(f'Unknown CONTACT_GEOMETRY: {CONTACT_GEOMETRY}')
print(f'Contact geometry: {CONTACT_GEOMETRY}; output: {OUTPUT_FILE}')
# Out:
# Contact geometry: spheres6; output: result_HC/p10/huntcrossley_6spheres/standing.pkl

# %%
model = load_model(MODEL_FILE, force_rebuild=True)
contact = model.gc_model
print(type(contact).__name__)
print(f'k={contact.k:g}, dissipation={contact.c:g}, transition velocity={contact.v_t:g}')
for feature, ground in contact.pairs:
    radius = getattr(feature, 'radius', None)
    radius_text = '' if radius is None else f' radius={radius:g}'
    print(f'{feature.name:7s} body={feature.parent_body:6s} position={feature.pos}{radius_text}')
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# Replacing dynamic symbols in the EOM with the v_ states, this might take a while...
# HuntCrossley
# k=1.2e+06, dissipation=2, transition velocity=0.1
# heel_r  body=foot_r position=[-0.0430481481, -0.0759763333, 0.0] radius=0.03
# rear_mid_r body=foot_r position=[0.0009738124, -0.0759763333, 0.0] radius=0.03
# mid_r   body=foot_r position=[0.0449957728, -0.0759763333, 0.0] radius=0.03
# fore_mid_r body=foot_r position=[0.0890177333, -0.0759763333, 0.0] radius=0.03
# forefoot_r body=foot_r position=[0.1330396938, -0.0759763333, 0.0] radius=0.03
# toe_r   body=foot_r position=[0.1770616542, -0.0759763333, 0.0] radius=0.03
# heel_l  body=foot_l position=[-0.0430481481, -0.0759763333, 0.0] radius=0.03
# rear_mid_l body=foot_l position=[0.0009738124, -0.0759763333, 0.0] radius=0.03
# mid_l   body=foot_l position=[0.0449957728, -0.0759763333, 0.0] radius=0.03
# fore_mid_l body=foot_l position=[0.0890177333, -0.0759763333, 0.0] radius=0.03
# forefoot_l body=foot_l position=[0.1330396938, -0.0759763333, 0.0] radius=0.03
# toe_l   body=foot_l position=[0.1770616542, -0.0759763333, 0.0] radius=0.03

# %% [markdown]
# ## Construct and adjust the initial pose
#
# The canonical points use the original 51 mm pelvis lift. The sphere centers retain those point locations, so the sphere condition adds the 30 mm radius and uses 81 mm. Re-run from the configuration cell after switching geometry.

# %%
problem = Collocation(STANDING_CONFIG, force_rebuild=False)
q_guess = np.asarray(problem.initial_guess_states.q).copy()
pelvis_ty = model.coordinates.names.index('q_pelvis_ty')
q_guess[:, pelvis_ty] = PELVIS_LIFT_M
problem.initial_guess_states = problem.initial_guess_states.replace(q=jnp.asarray(q_guess))
problem.setup()

state0 = calc_forces(problem.initial_guess_states[0], model)
forces = np.asarray(state0.ext_forces).reshape(-1, 3)
print('Contact forces [right foot, left foot] (N):')
print(forces)
print('Total vertical GRF:', forces[:, 1].sum(), 'N')
print('Body weight:', float(model.default_constants.mass.sum() * 9.81), 'N')
# Out:
# Loading model from cache: cf2a03f21067b879425c6a9049e798362a6dd0b3d98e240075b64f4478f9fa5b_x64_eom_nomusclefit.cpkl
# Collocation warning in process collocation settings: Bounds are not correctly handled
# Adding constraint: dynamics with weight 1.0, ncons=41, nnz=2706
# Adding objective: effort_term with weight 1.0
# Found 229 nonzeros in jacobian structure
# 8.46% of the (sparse) jacobian is nonzero
# 8.46% of the full jacobian is nonzero
# Found 229 nonzeros in jacobian structure
# 8.46% of the (sparse) jacobian is nonzero
# 8.46% of the full jacobian is nonzero
# Contact forces [right foot, left foot] (N):
# [[-2.59026926e-14  4.23023072e+02  0.00000000e+00]
#  [-2.59026926e-14  4.23023072e+02  0.00000000e+00]]
# Total vertical GRF: 846.0461445525499 N
# Body weight: 1009.8414 N

# %%
objective0 = problem.objective.objfun(problem.initial_guess_states, problem.initial_guess_globals)
constraints0 = problem.constraints.confun(problem.initial_guess_states, problem.initial_guess_globals)
print('Initial objective:', float(objective0))
print('Maximum initial constraint residual:', float(jnp.max(jnp.abs(constraints0))))
# Out:
# Initial objective: 0.0
# Maximum initial constraint residual: 222.8945672771276

# %% [markdown]
# ## Five-seed standing optimization
#
# Each trial starts from the geometry-specific pelvis lift and receives reproducible Gaussian perturbations in pelvis tilt and the six leg joint angles. Trial results are not written to the final standing file. Feasible trials are ranked by IPOPT objective.

# %%
SEEDS = [None, 1, 2, 3, 4]
ANGLE_NOISE_RAD = 0.01

def build_seeded_problem(seed, save_output=False):
    trial = Collocation(STANDING_CONFIG, force_rebuild=False)
    if not save_output:
        trial.settings['settings'].pop('output', None)

    q = np.asarray(trial.initial_guess_states.q).copy()
    q[:, trial.model.coordinates.names.index('q_pelvis_ty')] = PELVIS_LIFT_M
    perturb_names = [
        'q_pelvis_tilt', 'q_hip_r', 'q_knee_r', 'q_ankle_r',
        'q_hip_l', 'q_knee_l', 'q_ankle_l',
    ]
    perturb_idx = [trial.model.coordinates.names.index(name) for name in perturb_names]
    if seed is not None:
        rng = np.random.default_rng(seed)
        q[:, perturb_idx] += rng.normal(0.0, ANGLE_NOISE_RAD, size=(q.shape[0], len(perturb_idx)))

    q_min = np.asarray(trial.settings['bounds']['min'].q)
    q_max = np.asarray(trial.settings['bounds']['max'].q)
    q = np.clip(q, q_min, q_max)
    trial.initial_guess_states = trial.initial_guess_states.replace(q=jnp.asarray(q))
    trial.setup()
    return trial

def solution_metrics(trial, solution):
    objective = float(solution.info['obj_val']) if 'obj_val' in solution.info else float(trial.objective.objfun(solution.states, solution.globals))
    residual = trial.constraints.confun(solution.states, solution.globals)
    max_residual = float(jnp.max(jnp.abs(residual)))
    status = int(solution.info['status'])
    feasibility_tolerance = float(trial.settings['settings'].get('constr_viol_tol', 5e-3))
    feasible = status in (0, 1) and max_residual <= feasibility_tolerance
    return objective, max_residual, status, feasible

# %%
multistart_results = []
for seed in SEEDS:
    print(f'\n=== standing seed {seed} ===')
    trial = build_seeded_problem(seed, save_output=False)
    trial_solution = trial.solve(visualize=False)
    objective, max_residual, status, feasible = solution_metrics(trial, trial_solution)
    multistart_results.append({
        'seed': seed, 'objective': objective, 'max_residual': max_residual,
        'status': status, 'feasible': feasible, 'solution': trial_solution,
    })
    print(f'seed={seed}, objective={objective:.8g}, max residual={max_residual:.3g}, status={status}, feasible={feasible}')

feasible_results = [item for item in multistart_results if item['feasible']]
if feasible_results:
    best_standing_guess = min(feasible_results, key=lambda item: item['objective'])
else:
    best_standing_guess = min(multistart_results, key=lambda item: (item['max_residual'], item['objective']))
    print('WARNING: no seed met the feasibility criterion; selecting the smallest residual.')

print('\nSeed summary:')
for item in multistart_results:
    print(f"  seed {item['seed']}: objective={item['objective']:.8g}, residual={item['max_residual']:.3g}, feasible={item['feasible']}")
print(f"\nBest seed: {best_standing_guess['seed']}")
# Out:
# === standing seed None ===
# Loading model from cache: cf2a03f21067b879425c6a9049e798362a6dd0b3d98e240075b64f4478f9fa5b_x64_eom_nomusclefit.cpkl
# Collocation warning in process collocation settings: Bounds are not correctly handled
# Adding constraint: dynamics with weight 1.0, ncons=41, nnz=2706
# Adding objective: effort_term with weight 1.0
# Found 229 nonzeros in jacobian structure
# 8.46% of the (sparse) jacobian is nonzero
# 8.46% of the full jacobian is nonzero
# Found 229 nonzeros in jacobian structure
# 8.46% of the (sparse) jacobian is nonzero
# 8.46% of the full jacobian is nonzero
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.16, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      225
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       65
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       65
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       41
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  9.9999700e-07 2.18e+02 1.78e-05   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1
-03    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 44
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.8676153322090772e-04    7.8676153322090772e-04
# Dual infeasibility......:   6.8244171762496132e-05    6.8244171762496132e-05
# Constraint violation....:   3.6469009202171575e-04    2.6920392817682947e-03
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   8.9173494328254826e-07    8.9173494328254826e-07
# Overall NLP error.......:   3.6469009202171575e-04    2.6920392817682947e-03
#
#
# Number of objective function evaluations             = 46
# Number of objective gradient evaluations             = 45
# Number of equality constraint evaluations            = 46
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 45
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total seconds in IPOPT (w/o function evaluations)    =      2.451
# Total seconds in NLP function evaluations            =      0.739
#
#
# Timing Statistics:
#
# OverallAlgorithm....................:      3.008 (sys:      0.194 wall:      3.190)
#  PrintProblemStatistics.............:      0.000 (sys:      0.000 wall:      0.000)
#  InitializeIterates.................:      2.255 (sys:      0.128 wall:      2.382)
#  UpdateHessian......................:      0.002 (sys:      0.000 wall:      0.003)
#  OutputIteration....................:      0.001 (sys:      0.000 wall:      0.002)
#  UpdateBarrierParameter.............:      0.024 (sys:      0.019 wall:      0.043)
#  ComputeSearchDirection.............:      0.005 (sys:      0.004 wall:      0.009)
#  ComputeAcceptableTrialPoint........:      0.034 (sys:      0.016 wall:      0.057)
#  AcceptTrialPoint...................:      0.001 (sys:      0.000 wall:      0.001)
#  CheckConvergence...................:      0.684 (sys:      0.024 wall:      0.690)
# PDSystemSolverTotal.................:      0.015 (sys:      0.007 wall:      0.022)
#  PDSystemSolverSolveOnce............:      0.013 (sys:      0.005 wall:      0.017)
#  ComputeResiduals...................:      0.001 (sys:      0.001 wall:      0.001)
#  StdAugSystemSolverMultiSolve.......:      0.007 (sys:      0.002 wall:      0.009)
#  LinearSystemScaling................:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemSymbolicFactorization..:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemFactorization..........:      0.001 (sys:      0.000 wall:      0.001)
#  LinearSystemBackSolve..............:      0.001 (sys:      0.001 wall:      0.002)
#  LinearSystemStructureConverter.....:      0.000 (sys:      0.000 wall:      0.000)
#   LinearSystemStructureConverterInit:      0.000 (sys:      0.000 wall:      0.000)
# QualityFunctionSearch...............:      0.012 (sys:      0.015 wall:      0.027)
# TryCorrector........................:      0.000 (sys:      0.000 wall:      0.000)
# Task1...............................:      0.002 (sys:      0.003 wall:      0.005)
# Task2...............................:      0.001 (sys:      0.002 wall:      0.003)
# Task3...............................:      0.001 (sys:      0.001 wall:      0.003)
# Task4...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task5...............................:      0.001 (sys:      0.002 wall:      0.003)
# Task6...............................:      0.000 (sys:      0.000 wall:      0.000)
# Function Evaluations................:      0.711 (sys:      0.039 wall:      0.739)
#  Objective function.................:      0.069 (sys:      0.010 wall:      0.074)
#  Objective function gradient........:      0.006 (sys:      0.001 wall:      0.008)
#  Equality constraints...............:      0.590 (sys:      0.018 wall:      0.603)
#  Inequality constraints.............:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraint Jacobian.......:      0.046 (sys:      0.009 wall:      0.054)
#  Inequality constraint Jacobian.....:      0.000 (sys:      0.000 wall:      0.000)
#  Lagrangian Hessian.................:      0.000 (sys:      0.000 wall:      0.000)
#
# EXIT: Optimal Solution Found.
# seed=3, objective=0.00078676153, max residual=0.00269, status=0, feasible=True
#
# === standing seed 4 ===
# Loading model from cache: cf2a03f21067b879425c6a9049e798362a6dd0b3d98e240075b64f4478f9fa5b_x64_eom_nomusclefit.cpkl
# Collocation warning in process collocation settings: Bounds are not correctly handled
# Adding constraint: dynamics with weight 1.0, ncons=41, nnz=2706
# Adding objective: effort_term with weight 1.0
# Found 229 nonzeros in jacobian structure
# 8.46% of the (sparse) jacobian is nonzero
# 8.46% of the full jacobian is nonzero
# Found 229 nonzeros in jacobian structure
# 8.46% of the (sparse) jacobian is nonzero
# 8.46% of the full jacobian is nonzero
# This is Ipopt version 3.14.16, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      225
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       65
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       65
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       41
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  9.9999700e-07 2.22e+02 1.89e-05   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  9.8785695e-07 2.17e+02 8.76e-01  -6.0 6.59e-01    -  1.48e-02 2.06e-02h  1
#    2  1.1494348e-06 1.94e+02 4.37e+00  -6.1 6.67e-01    -  3.30e-02 1.07e-01h  1
#    3  1.1494573e-06 1.94e+02 5.61e+05  -0.7 1.51e+00    -  4.13e-01 3.81e-07f  1
#    4  1.7363098e-06 1.79e+02 5.04e+05  -1.9 6.25e-01    -  1.32e-01 8.31e-02h  1
#    5  3.0485817e-03 4.46e+01 4.13e+05  -1.1 6.65e-01    -  7.94e-01 1.00e+00f  1
#    6  2.1532076e-02 1.16e+01 8.49e+05  -1.1 4.57e-01    -  7.01e-01 9.77e-01h  1
#    7  7.5919009e-02 4.22e+00 4.55e+07  -0.7 4.83e-01    -  1.00e+00 7.68e-01f  1
#    8  6.6210931e-02 1.00e+00 1.02e+07  -0.4 6.05e-01    -  1.00e+00 1.00e+00f  1
#    9  7.0314008e-02 9.84e-01 1.23e+11   1.6 3.50e+03    -  5.63e-05 2.32e-05H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.1324954e-01 1.00e+00 3.55e+07   0.2 5.92e-01    -  1.00e+00 9.32e-01h  1
#   11r 1.1324954e-01 1.00e+00 7.93e+02   2.2 0.00e+00    -  0.00e+00 2.65e-07R  8
#   12r 1.1324742e-01 1.00e+00 2.69e+00   0.6 2.62e+00    -  9.96e-01 1.09e-05f  1
#   13r 7.0590605e-02 1.00e+00 9.37e+00   0.3 1.72e+00    -  1.00e+00 9.84e-01f  1

# Task6...............................:      0.000 (sys:      0.000 wall:      0.000)
# Function Evaluations................:      0.702 (sys:      0.032 wall:      0.690)
#  Objective function.................:      0.064 (sys:      0.005 wall:      0.065)
#  Objective function gradient........:      0.004 (sys:      0.001 wall:      0.005)
#  Equality constraints...............:      0.599 (sys:      0.018 wall:      0.598)
#  Inequality constraints.............:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraint Jacobian.......:      0.034 (sys:      0.007 wall:      0.023)
#  Inequality constraint Jacobian.....:      0.000 (sys:      0.000 wall:      0.000)
#  Lagrangian Hessian.................:      0.000 (sys:      0.000 wall:      0.000)
#
# EXIT: Optimal Solution Found.
# seed=4, objective=0.00078255603, max residual=0.00127, status=0, feasible=True
#
# Seed summary:
#   seed None: objective=1.0366426e-06, residual=0.000579, feasible=True
#   seed 1: objective=3.4165845e-06, residual=0.000585, feasible=True
#   seed 2: objective=3.6190847e-07, residual=0.000143, feasible=True
#   seed 3: objective=0.00078676153, residual=0.00269, feasible=True
#   seed 4: objective=0.00078255603, residual=0.00127, feasible=True
#
# Best seed: 2

# %% [markdown]
# ## Repeat the best seed and save it
#
# This creates a fresh problem with output enabled, repeats the winning seed, and writes the final initial guess to the geometry-specific `OUTPUT_FILE`.

# %%
# Recompute the winner here from the latest trial list. This prevents a
# stale best_standing_guess from an earlier out-of-order notebook run.
latest_feasible = [item for item in multistart_results if item['feasible']]
if latest_feasible:
    best_standing_guess = min(latest_feasible, key=lambda item: item['objective'])
else:
    best_standing_guess = min(multistart_results, key=lambda item: (item['max_residual'], item['objective']))
best_seed = best_standing_guess['seed']
final_problem = build_seeded_problem(best_seed, save_output=True)
solution = final_problem.solve(visualize=True)
final_objective, final_residual, final_status, final_feasible = solution_metrics(final_problem, solution)
print(f'Best seed {best_seed}: objective={final_objective:.8g}, max residual={final_residual:.3g}, status={final_status}')
print('Saved:', OUTPUT_FILE.resolve())

log_file = OUTPUT_FILE.with_name('standing_multistart.tsv')
with log_file.open('w', encoding='utf-8') as handle:
    handle.write('seed\tobjective\tmax_residual\tstatus\tfeasible\n')
    for item in multistart_results:
        handle.write(f"{item['seed']}\t{item['objective']:.16g}\t{item['max_residual']:.16g}\t{item['status']}\t{item['feasible']}\n")
    handle.write(f'best_seed\t{best_seed}\n')
print('Saved seed comparison:', log_file.resolve())
# Out:
# Loading model from cache: cf2a03f21067b879425c6a9049e798362a6dd0b3d98e240075b64f4478f9fa5b_x64_eom_nomusclefit.cpkl
# Collocation warning in process collocation settings: Bounds are not correctly handled
# Adding constraint: dynamics with weight 1.0, ncons=41, nnz=2706
# Adding objective: effort_term with weight 1.0
# Found 229 nonzeros in jacobian structure
# 8.46% of the (sparse) jacobian is nonzero
# 8.46% of the full jacobian is nonzero
# Found 229 nonzeros in jacobian structure
# 8.46% of the (sparse) jacobian is nonzero
# 8.46% of the full jacobian is nonzero
# This is Ipopt version 3.14.16, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      225
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       65
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       65
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       41
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  9.9999700e-07 2.19e+02 1.90e-05   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  9.8044718e-07 2.16e+02 4.10e-01  -6.0 6.80e-01    -  1.44e-02 1.35e-02h  1
#    2  1.4683999e-06 1.91e+02 1.36e+01  -6.1 6.83e-01    -  2.68e-02 1.18e-01h  1
#    3  1.4684211e-06 1.91e+02 6.42e+05  -1.0 7.54e-01    -  6.16e-01 6.10e-07f  1
#    4  2.2301833e-06 1.78e+02 5.82e+05  -2.5 6.32e-01    -  1.27e-01 7.33e-02h  1
#    5  1.4903194e-03 4.44e+01 4.10e+04  -1.3 6.55e-01    -  3.87e-01 1.00e+00f  1
# Number of equality constraint evaluations            = 29
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 29
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total seconds in IPOPT (w/o function evaluations)    =      2.664
# Total seconds in NLP function evaluations            =      0.943
#
#
# Timing Statistics:
#
# OverallAlgorithm....................:      3.536 (sys:      0.159 wall:      3.607)
#  PrintProblemStatistics.............:      0.000 (sys:      0.000 wall:      0.000)
#  InitializeIterates.................:      2.558 (sys:      0.112 wall:      2.606)
#  UpdateHessian......................:      0.003 (sys:      0.000 wall:      0.003)
#  OutputIteration....................:      0.002 (sys:      0.000 wall:      0.002)
#  UpdateBarrierParameter.............:      0.024 (sys:      0.012 wall:      0.037)
#  ComputeSearchDirection.............:      0.003 (sys:      0.004 wall:      0.006)
#  ComputeAcceptableTrialPoint........:      0.036 (sys:      0.015 wall:      0.051)
#  AcceptTrialPoint...................:      0.001 (sys:      0.000 wall:      0.001)
#  CheckConvergence...................:      0.907 (sys:      0.016 wall:      0.899)
# PDSystemSolverTotal.................:      0.013 (sys:      0.005 wall:      0.019)
#  PDSystemSolverSolveOnce............:      0.012 (sys:      0.004 wall:      0.015)
#  ComputeResiduals...................:      0.000 (sys:      0.001 wall:      0.001)
#  StdAugSystemSolverMultiSolve.......:      0.006 (sys:      0.002 wall:      0.008)
#  LinearSystemScaling................:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemSymbolicFactorization..:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemFactorization..........:      0.001 (sys:      0.000 wall:      0.001)
#  LinearSystemBackSolve..............:      0.001 (sys:      0.000 wall:      0.002)
#  LinearSystemStructureConverter.....:      0.000 (sys:      0.000 wall:      0.000)
#   LinearSystemStructureConverterInit:      0.000 (sys:      0.000 wall:      0.000)
# QualityFunctionSearch...............:      0.012 (sys:      0.009 wall:      0.021)
# TryCorrector........................:      0.000 (sys:      0.000 wall:      0.000)
# Task1...............................:      0.002 (sys:      0.002 wall:      0.004)
# Task2...............................:      0.001 (sys:      0.001 wall:      0.002)
# Task3...............................:      0.001 (sys:      0.001 wall:      0.002)
# Task4...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task5...............................:      0.001 (sys:      0.001 wall:      0.002)
# Task6...............................:      0.000 (sys:      0.000 wall:      0.000)
# Function Evaluations................:      0.937 (sys:      0.030 wall:      0.943)
#  Objective function.................:      0.073 (sys:      0.005 wall:      0.074)
#  Objective function gradient........:      0.006 (sys:      0.000 wall:      0.007)
#  Equality constraints...............:      0.813 (sys:      0.018 wall:      0.828)
#  Inequality constraints.............:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraint Jacobian.......:      0.045 (sys:      0.006 wall:      0.034)
#  Inequality constraint Jacobian.....:      0.000 (sys:      0.000 wall:      0.000)
#  Lagrangian Hessian.................:      0.000 (sys:      0.000 wall:      0.000)
#
# EXIT: Optimal Solution Found.
# Saving results to result_HC/p10/huntcrossley_6spheres/standing.pkl
# Best seed 2: objective=3.6190847e-07, max residual=0.000143, status=0
# Saved: result_HC/p10/huntcrossley_6spheres/standing.pkl
# Saved seed comparison: result_HC/p10/huntcrossley_6spheres/standing_multistart.tsv

# %%
solved_state = calc_forces(solution.states[0], model)
solved_forces = np.asarray(solved_state.ext_forces).reshape(-1, 3)
labels = ['right', 'left']
plt.bar(labels, solved_forces[:, 1])
plt.axhline(float(model.default_constants.mass.sum() * 9.81 / 2), color='k', linestyle='--', label='BW / 2')
plt.ylabel('Vertical GRF (N)')
plt.legend();
print('Solved contact forces (N):\n', solved_forces)
# Out:
# Solved contact forces (N):
#  [[-4.21877014e-06  9.17294236e+02  0.00000000e+00]
#  [ 4.85970194e-06  9.24828641e+01  0.00000000e+00]]
